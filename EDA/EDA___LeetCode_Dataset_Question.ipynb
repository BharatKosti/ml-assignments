# %% [markdown]
# # Please make a copy of this notebook and try solving the below questions in your notebook copy. Solutions for these will be discussed in the assignment review session on <day> post which, we will also share the solution notebook.
#
#
# # **Good Luck**

# %% [markdown]
# ## LeetCode DataSet
# It contains the following info:
#
# **id**: problem id
# **title**: problem name
# **description**: problem description
# **is_premium**: whether the questions requires a premium account
# **difficulty**: easy, medium, or hard
# **solution_link**: how often the answer submitted is correct
# **acceptance_rate**: how often the answer submitted is correct
# **frequency**: how often the problem is attempted
# **url**: url to the problem
# **discuss_count**: how many comments are submitted by users
# **accepted**: how many times the answer was accepted
# **submissions**: how many times the answer was submitted
# **companies**: which companies were tagged as having asked this specific problem
# **related_topics**: related topics to the current problem
# **likes**: how many likes the problem got
# **dislikes**: how many dislikes the problem got
# **rating**: likes / (likes + dislikes)
# **asked_by_faang**: whether or not the question was asked by facebook, apple, amazon, google, or netflix
# **similar_questions**: similar problems with problem name, slug, and difficulty

# %% [markdown]
# ## Question 1
# #### What is the Shape of the dataset?

# %%
#Solution 1(your code here)
# !pip install pandas 
# !pip install seaborn
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: seaborn in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: matplotlib in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/bharatkosti/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
df = pd.read_csv('leetcode_dataset - lc.csv')
df.shape
df.columns.size
df
# Out:
#         id                                           title  \
# 0        1                                         Two Sum
# 1        2                                 Add Two Numbers
# 2        3  Longest Substring Without Repeating Characters
# 3        4                     Median of Two Sorted Arrays
# 4        5                   Longest Palindromic Substring
# ...    ...                                             ...
# 1820  1821  Find Customers With Positive Revenue this Year
# 1821  1822                 Sign of the Product of an Array
# 1822  1823            Find the Winner of the Circular Game
# 1823  1824                           Minimum Sideway Jumps
# 1824  1825                              Finding MK Average
#
#                                             description  is_premium  \
# 0     Given an array of integers `nums` and an integ...           0
# 1     You are given two non-empty linked lists repre...           0
# 2     Given a string `s`, find the length of the lon...           0
# 3     Given two sorted arrays `nums1` and `nums2` of...           0
# 4     Given a string `s`, return the longest palindr...           0
# ...                                                 ...         ...
# 1820                                         SQL Schema           1
# 1821  There is a function `signFunc(x)` that returns...           0
# 1822  There are `n` friends that are playing a game....           0
# 1823  There is a 3 lane road of length `n` that cons...           0
# 1824  You are given two integers, `m` and `k`, and a...           0
#
#      difficulty                                      solution_link  \
# 0          Easy                                  /articles/two-sum
# 1        Medium                          /articles/add-two-numbers
# 2        Medium  /articles/longest-substring-without-repeating-...
# 3          Hard              /articles/median-of-two-sorted-arrays
# 4        Medium            /articles/longest-palindromic-substring
# ...         ...                                                ...
# 1820       Easy                                                NaN
# 1821       Easy                                                NaN
# 1822     Medium                                                NaN
# 1823     Medium                                                NaN
# 1824       Hard                                                NaN
#
#       acceptance_rate  frequency  \
# 0                46.7      100.0
# 1                35.7       93.1
# 2                31.5       90.9
# 3                31.4       86.2
# 4                30.6       84.7
# ...               ...        ...
# 1820             88.9        0.0
# 1821             67.8        0.0
# 1822             71.8        0.0
# 1823             47.2        0.0
# 1824             28.1        0.0
#
#                                                     url  discuss_count  \
# 0                 https://leetcode.com/problems/two-sum            999
# 1         https://leetcode.com/problems/add-two-numbers            999
# 2     https://leetcode.com/problems/longest-substrin...            999
# 3     https://leetcode.com/problems/median-of-two-so...            999
# 4     https://leetcode.com/problems/longest-palindro...            999
# ...                                                 ...            ...
# 1820  https://leetcode.com/problems/find-customers-w...             15
# 1821  https://leetcode.com/problems/sign-of-the-prod...            104
# 1822  https://leetcode.com/problems/find-the-winner-...            135
# 1823  https://leetcode.com/problems/minimum-sideway-...            134
# 1824   https://leetcode.com/problems/finding-mk-average             48
#
#      accepted submissions                                          companies  \
# 0        4.1M        8.7M  Amazon,Google,Apple,Adobe,Microsoft,Bloomberg,...
# 1        1.9M        5.2M  Bloomberg,Microsoft,Amazon,Google,Facebook,App...
# 2        2.1M        6.7M  Amazon,Bloomberg,Microsoft,Facebook,Apple,Adob...
# 3      904.7K        2.9M  Amazon,Goldman Sachs,Facebook,Microsoft,Apple,...
# 4        1.3M        4.1M  Amazon,Microsoft,Wayfair,Facebook,Adobe,eBay,G...
# ...       ...         ...                                                ...
# 1820      305         343                                             Google
# 1821     7.9K       11.7K                                          Microsoft
# 1822     6.8K        9.5K                                          Bloomberg
# 1823       5K       10.7K                                            Pony.ai
# 1824     2.1K        7.4K                                             Google
#
#                                      related_topics  likes  dislikes  rating  \
# 0                                  Array,Hash Table  20217       712      97
# 1                        Linked List,Math,Recursion  11350      2704      81
# 2     Hash Table,Two Pointers,String,Sliding Window  13810       714      95
# 3            Array,Binary Search,Divide and Conquer   9665      1486      87
# 4                        String,Dynamic Programming  10271       670      94
# ...                                             ...    ...       ...     ...
# 1820                                            NaN      2         2      50
# 1821                                           Math     37         4      90
# 1822                                          Array     81         4      95
# 1823       Dynamic Programming,Breadth-first Search    147         8      95
# 1824                              Heap,Design,Queue     52        43      55
#
#       asked_by_faang                                  similar_questions
# 0                  1  [3Sum, /problems/3sum/, Medium], [4Sum, /probl...
# 1                  1  [Multiply Strings, /problems/multiply-strings/...
# 2                  1  [Longest Substring with At Most Two Distinct C...
# 3                  1                                                NaN
# 4                  1  [Shortest Palindrome, /problems/shortest-palin...
# ...              ...                                                ...
# 1820               1                                                NaN
# 1821               0                                                NaN
# 1822               0                                                NaN
# 1823               0            [Frog Jump, /problems/frog-jump/, Hard]
# 1824               1  [Find Median from Data Stream, /problems/find-...
#
# [1825 rows x 19 columns]

# %% [markdown]
# ## Question 2
# #### What is the datatype of **accepted** and **acceptance rate** fields?

# %%
print(type(df['accepted']))
print(type(df['acceptance_rate'])) #Solution 2(your code here)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Question 3
# #### What is the number of missing values correponsing to each field?

# %%
#Solution 3(your code here)
df.isnull().sum()
# Out:
# id                      0
# title                   0
# description             0
# is_premium              0
# difficulty              0
# solution_link         838
# acceptance_rate         0
# frequency               0
# url                     0
# discuss_count           0
# accepted                0
# submissions             0
# companies              76
# related_topics        254
# likes                   0
# dislikes                0
# rating                  0
# asked_by_faang          0
# similar_questions    1080
# dtype: int64

# %% [markdown]
# ## Question 4
# #### What is the cardinality of the columns?

# %%
#Solution 4(your code here)
df.nunique()
# Out:
# id                   1825
# title                1825
# description          1670
# is_premium              2
# difficulty              3
# solution_link         987
# acceptance_rate       576
# frequency             619
# url                  1825
# discuss_count         642
# accepted             1098
# submissions          1236
# companies             691
# related_topics        320
# likes                1161
# dislikes              603
# rating                 94
# asked_by_faang          2
# similar_questions     689
# dtype: int64

# %% [markdown]
# ## Question 5
# #### Give 2 inferences from the .describe() of the dataset.

# %%
#Solution 5(your code here)
df.describe()
#mean acceptance rate is 53.13%
#Standard deviation of rating is 23.31%
# Out:
#                 id   is_premium  acceptance_rate    frequency  discuss_count  \
# count  1825.000000  1825.000000      1825.000000  1825.000000    1825.000000
# mean    913.000000     0.218082        53.139616    21.113041     421.435068
# std     526.976438     0.413057        14.778411    22.364741     330.583617
# min       1.000000     0.000000        13.900000     0.000000       9.000000
# 25%     457.000000     0.000000        42.400000     3.100000     150.000000
# 50%     913.000000     0.000000        51.600000    13.500000     292.000000
# 75%    1369.000000     0.000000        62.800000    31.800000     663.000000
# max    1825.000000     1.000000        95.600000   100.000000     999.000000
#
#               likes     dislikes       rating  asked_by_faang
# count   1825.000000  1825.000000  1825.000000     1825.000000
# mean    1050.534795   279.010959    77.391233        0.671233
# std     1512.674013   608.489206    23.317515        0.469894
# min        2.000000     0.000000     7.000000        0.000000
# 25%      217.000000    32.000000    67.000000        0.000000
# 50%      516.000000    92.000000    88.000000        1.000000
# 75%     1200.000000   239.000000    95.000000        1.000000
# max    20217.000000  8900.000000   100.000000        1.000000

# %% [markdown]
# ## Question 6
# #### Plot the outliners in the dataset.

# %%
#Solution 6(your code here)
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x=df['frequency'], sym='*')
plt.show()

# %% [markdown]
# ## Question 7
# #### **is_premium**, **difficulty** , **rating** and **asked_by_faang** are four important parameters in the dataset. Plot/calculate all possible relation between them and explain the relationship.

# %%
#Solution 7(your code here)
sns.pairplot(df, vars=['is_premium', 'difficulty', 'rating', 'asked_by_faang'])

# %%
plt.figure(figsize=(50, 50)) 
sns.countplot(x='frequency', hue='difficulty', data=df)
plt.show()

# %%
sns.countplot(x='is_premium', hue='difficulty', data=df)
# Out:
# <AxesSubplot:xlabel='is_premium', ylabel='count'>

# %% [markdown]
# ## Question 8
# #### Plot top 20 companies whose problems are listed in this dataset.

# %%
#Solution 8(your code here)
plt.figure(figsize=(50, 50)) 
sns.countplot(x='companies', data=df, order=df['companies'].value_counts().iloc[:20].index)
plt.show()
